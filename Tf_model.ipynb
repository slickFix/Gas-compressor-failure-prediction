# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import os

# %%
os.getcwd()
# Out:
# '/home/siddharth/workspace-jn/Gas_compressor_failure_prediction'

# %%
os.chdir('/home/siddharth/Downloads/Dataset/P_projects/Turbine data')

# %%
df  = pd.read_excel('30k_records.xlsx')

# %%
pd.set_option('max_colwidth', 800)
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 589223 entries, 0 to 589222
# Data columns (total 31 columns):
# lever             589223 non-null float64
# speed             589223 non-null int64
# gt_shaft_tq       589223 non-null float64
# gt_speed          589223 non-null float64
# cpp_th            589223 non-null float64
# cpp_tn            589223 non-null float64
# shaft_tq_pt       589223 non-null int64
# shaft_rpm_pt      589223 non-null float64
# shaft_tq_Q        589223 non-null int64
# shaft_rpm_stbd    589223 non-null float64
# hp_turb_ex_T      589223 non-null float64
# gg_speed          589223 non-null float64
# ff_mf             589223 non-null float64
# abb_Tic           589223 non-null float64
# gt_cmpr_outP      589223 non-null float64
# gt_cmpr_outT      589223 non-null float64
# pext_bar          589223 non-null float64
# hp_turb_outP      589223 non-null float64
# tcs_signal        589223 non-null float64
# th_coef_st        589223 non-null float64
# ...

# %%
df.describe()
# Out:
#                lever          speed    gt_shaft_tq       gt_speed  \
# count  589223.000000  589223.000000  589223.000000  589223.000000
# mean        5.166087      14.998177   29929.568972    2135.231645
# std         2.626230       7.745928   24178.106721     770.738707
# min         1.137900       3.000000     241.320000    1306.900000
# 25%         3.143800       9.000000    8845.600000    1386.800000
# 50%         5.140400      15.000000   23814.000000    1924.600000
# 75%         7.148100      21.000000   44822.000000    2678.100000
# max         9.300000      27.000000   83143.000000    3570.300000
#
#               cpp_th         cpp_tn    shaft_tq_pt   shaft_rpm_pt  \
# count  589223.000000  589223.000000  589223.000000  589223.000000
# mean      232.376110     232.376110  341583.985729      93.502109
# std       201.792355     201.792355  276110.048220      33.750726
# min         5.307600       5.307600   34810.000000      57.228000
# ...

# %%
df = df.drop(['prop_th_dcy','hull_dcy','gt_turb_dcy','output_class'],axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 589223 entries, 0 to 589222
# Data columns (total 27 columns):
# lever             589223 non-null float64
# speed             589223 non-null int64
# gt_shaft_tq       589223 non-null float64
# gt_speed          589223 non-null float64
# cpp_th            589223 non-null float64
# cpp_tn            589223 non-null float64
# shaft_tq_pt       589223 non-null int64
# shaft_rpm_pt      589223 non-null float64
# shaft_tq_Q        589223 non-null int64
# shaft_rpm_stbd    589223 non-null float64
# hp_turb_ex_T      589223 non-null float64
# gg_speed          589223 non-null float64
# ff_mf             589223 non-null float64
# abb_Tic           589223 non-null float64
# gt_cmpr_outP      589223 non-null float64
# gt_cmpr_outT      589223 non-null float64
# pext_bar          589223 non-null float64
# hp_turb_outP      589223 non-null float64
# tcs_signal        589223 non-null float64
# th_coef_st        589223 non-null float64
# ...

# %% [markdown]
# ### Reducing the dataset size for testing

# %%
# reducing the dataset size for testing

df_t = df.sample(frac = 0.01,random_state = 101)

# %%
df_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5892 entries, 229707 to 519885
# Data columns (total 27 columns):
# lever             5892 non-null float64
# speed             5892 non-null int64
# gt_shaft_tq       5892 non-null float64
# gt_speed          5892 non-null float64
# cpp_th            5892 non-null float64
# cpp_tn            5892 non-null float64
# shaft_tq_pt       5892 non-null int64
# shaft_rpm_pt      5892 non-null float64
# shaft_tq_Q        5892 non-null int64
# shaft_rpm_stbd    5892 non-null float64
# hp_turb_ex_T      5892 non-null float64
# gg_speed          5892 non-null float64
# ff_mf             5892 non-null float64
# abb_Tic           5892 non-null float64
# gt_cmpr_outP      5892 non-null float64
# gt_cmpr_outT      5892 non-null float64
# pext_bar          5892 non-null float64
# hp_turb_outP      5892 non-null float64
# tcs_signal        5892 non-null float64
# th_coef_st        5892 non-null float64
# prop_rps          5892 non-null float64
# ...

# %%
df_t.describe()
# Out:
#              lever        speed   gt_shaft_tq     gt_speed       cpp_th  \
# count  5892.000000  5892.000000   5892.000000  5892.000000  5892.000000
# mean      5.196293    15.088595  30196.661214  2145.674067   234.514979
# std       2.631530     7.760699  24164.353629   772.289182   202.032365
# min       1.137900     3.000000    297.120000  1307.300000     5.379700
# 25%       3.143800     9.000000   8872.825000  1386.800000    60.708500
# 50%       5.140400    15.000000  24020.500000  1924.600000   182.190000
# 75%       7.148100    21.000000  45316.500000  2678.100000   353.712500
# max       9.300000    27.000000  82843.000000  3565.800000   693.170000
#
#             cpp_tn    shaft_tq_pt  shaft_rpm_pt     shaft_tq_Q  \
# count  5892.000000    5892.000000   5892.000000    5892.000000
# mean    234.514979  344488.390699     93.959375  344488.390699
# std     202.032365  276134.961969     33.818649  276134.961969
# min       5.379700   34810.000000     57.246000   34810.000000
# ...

# %%
t
